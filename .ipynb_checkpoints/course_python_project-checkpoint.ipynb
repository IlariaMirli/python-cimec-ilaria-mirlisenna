# %% [markdown]
# **Import of the excel files**

# %%
# import of files and functions

import pandas as pd 
import numpy as np

# loading data
pilot_results = pd.read_excel('/Users/Ilaria/Library/CloudStorage/GoogleDrive-ilaria.mirlisenna@unitn.it/Il mio Drive/Projects/Uncertainty and Pain/Daniele/excel per analisi/RisultatiPilot.xlsx')
exp_results = pd.read_excel('/Users/Ilaria/Desktop/backup uncertainty /0707/risultatiparte2_corretto.xlsx')

# %%
# checking that the correct file have been loaded

#for exp_results we use head 
exp_results.head()

#for pilot_results we try with the whole doc
pilot_results
# Out:
# <bound method NDFrame.head of       Subj_ID Gender  Age Folder              Video  PainInitial  PainFinal  \
# 0           1      F   23      A    N female 47.mp4           39          1
# 1           1      F   23      A   HRP female 6.mp4           90          4
# 2           1      F   23      A   LRP female 9.mp4           83         11
# 3           1      F   23      A   LPP female 6.mp4           60         26
# 4           1      F   23      A   HRP Males 11.mp4           38         44
# ...       ...    ...  ...    ...                ...          ...        ...
# 1320       20      f   28      B    LRP Males 5.mp4           77         42
# 1321       20      f   28      B  HRP female 14.mp4           12         51
# 1322       20      f   28      B     N Males 18.mp4           98         60
# 1323       20      f   28      B   HPP female 4.mp4           68         81
# 1324       20      f   28      B     N Males 17.mp4           89         62
#
#       PainTime(s)  RealInitial  RealFinal  RealTime(s)
# 0        5.504070          999        999   999.000000
# 1        6.374260           69         19     6.361051
# 2       12.908778           77         22     4.823551
# 3        4.112881           70          1     7.141504
# 4        4.413016           42         80     4.488369
# ...           ...          ...        ...          ...
# 1320     2.241601           39         35     1.192649
# 1321    13.599626            3         59     2.966122
# 1322     2.752098          999        999   999.000000
# 1323     1.941841           72         22     2.381840
# 1324     2.321807          999        999   999.000000
#
# [1325 rows x 11 columns]>

# %%
# calculating the median values for the measures of interest for each video

# first, i identify all the videos
videos = pilot_results['Video'].unique()

# i initialize an empty list where i am gonna put the measures of interest 
table_median = []

for video in videos:
    curr_video = pilot_results[pilot_results['Video'] == video]
    table_median.append({
        'Video': video.replace('.mp4', ''),
        'MedianPainFinal': np.median(curr_video['PainFinal']),
        'MedianRealFinal': np.median(curr_video['RealFinal'])})

# i create a dataframe out of the list
table_median = pd.DataFrame(table_median)
table_median_sorted =  table_median.sort_values(by='Video')

#
# Out:
#             Video  MedianPainFinal  MedianRealFinal
# 40    HPP Males 1             71.5             64.0
# 65   HPP Males 10            100.0             36.5
# 34    HPP Males 2             69.5             35.0
# 98    HPP Males 3             82.0             71.0
# 105   HPP Males 4             65.5             73.0
# ..            ...              ...              ...
# 0     N female 47              7.5            999.0
# 100   N female 48              1.0            949.5
# 7     N female 49             48.0            999.0
# 63    N female 52              1.0            999.0
# 89    N female 53              1.0            949.5
#
# [132 rows x 3 columns]
